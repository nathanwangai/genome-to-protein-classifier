# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X = pd.read_excel('gene_features_dataset.xlsx')

print(X.groupby('class').mean())

y = X['class']
y = np.expand_dims(y, axis=1)
X = X.drop('class', axis=1)

print(y.shape)
print(X.shape)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
logreg = LogisticRegression(multi_class='multinomial', solver='newton-cg', max_iter = 100000)
# Out:
#          prop_A    prop_T    prop_C    prop_G   prop_NP    prop_P  prop_pos  \
# class
# 0      0.221384  0.244240  0.285415  0.248961  0.435615  0.205269  0.197767
# 1      0.229414  0.210855  0.271298  0.288433  0.508023  0.192388  0.170528
# 2      0.268921  0.229297  0.249421  0.252360  0.512545  0.202036  0.165830
# 3      0.255737  0.223211  0.246701  0.274350  0.494808  0.198515  0.177561
# 4      0.241131  0.225009  0.256857  0.277002  0.487723  0.194907  0.183590
# 5      0.256434  0.232731  0.252077  0.258757  0.487590  0.196016  0.174244
# 6      0.264443  0.200927  0.271914  0.262716  0.530836  0.194901  0.165165
#
#        prop_neg
# class
# 0      0.105533
# 1      0.084738
# 2      0.067141
# 3      0.078474
# 4      0.084391
# 5      0.084199
# 6      0.066820
# (4380, 1)
# (4380, 8)

# %%
logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)
print('The model is {0:.2f}% accurate \n'.format(logreg.score(X_test, y_test) * 100))

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
# The model is 38.51% accurate
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.61      0.59       155
#            1       0.00      0.00      0.00       169
#            2       0.00      0.00      0.00        93
#            3       0.26      0.08      0.12       197
#            4       0.29      0.18      0.22       220
#            5       0.00      0.00      0.00        75
#            6       0.38      0.88      0.53       405
#
#     accuracy                           0.39      1314
#    macro avg       0.21      0.25      0.21      1314
# weighted avg       0.27      0.39      0.29      1314
# C:\Users\Nathan\miniconda3\envs\tensorflow\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
