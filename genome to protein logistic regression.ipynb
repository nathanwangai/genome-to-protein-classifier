# %%
import pandas as pd
import numpy as np

human_data = pd.read_table('human_data.txt') # 'sequence' 'class'
human_data.head()
print("Num of gene sequences: " + str(human_data.shape[0]))

coding_strand = list(human_data['sequence'][1]) # coding strand 1

# new list with: 
# number of each base pair (A, T, C, G)
# number of each class of amino acid (non-polar, polar, +charge, -charge)

# def base_pair_fractions(sequence): 
 
aa_dict = [] #implement


# returns the polypeptide chain crresponding to DNA sequence
def protein_transform(sequence): 
    total_codons = sequence.size // 3
    base_sequence = sequence[:total_codons * 3]
    codon_sequence = base_sequence.reshape((total_codons, 3))
    
    aa_dict[''][]
    
    return codon_sequence

sequence = np.expand_dims(np.array(list('AAAGGGCCCTTT')), axis=0)
print(sequence.shape)

protein_transform(sequence).shape
# Out:
# Num of gene sequences: 4380
# (1, 12)
# (4, 3)

# %%
# Out:
# 228
